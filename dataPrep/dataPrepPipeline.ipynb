# %% [markdown]
# Uses the requirements.txt in the fast-speech-2 directory

# %%
# %conda install -c conda-forge montreal-forced-aligner
# %conda install -c conda-forge spacy sudachipy sudachidict-core
# Out:
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.7.0
#     latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/derekvawdrey/Workspace/School/CS479FinalProject/.conda
#
#   added / updated specs:
#     - montreal-forced-aligner
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     audioread-3.0.1            |  py311h267d04e_3          45 KB  conda-forge
#     biopython-1.86             |  py311h9408147_0         3.1 MB  conda-forge
#     brotli-python-1.2.0        |  py311h69b7e7c_0         351 KB  conda-forge
#     cffi-1.17.1                |  py311h3a79f62_0         281 KB  conda-forge
# ...

# %%
# !mfa model download acoustic japanese_mfa
# !mfa model download g2p japanese_mfa
# !mfa model download dictionary japanese_mfa
# Out:
# Local version of model already exists (/Users/derekvawdrey/Documents/MFA/pretrained_models/acoustic/japanese_mfa.zip). Use the --ignore_cache flag to force redownloading.
# Local version of model already exists (/Users/derekvawdrey/Documents/MFA/pretrained_models/g2p/japanese_mfa.zip). Use the --ignore_cache flag to force redownloading.
# Local version of model already exists (/Users/derekvawdrey/Documents/MFA/pretrained_models/dictionary/japanese_mfa.dict). Use the --ignore_cache flag to force redownloading.

# %%
# Out:
# /Users/derekvawdrey/anaconda3/envs/fastspeech/lib/python3.10/site-packages/Bio/pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(
# INFO - Saved model to f/Users/derekvawdrey/Documents/MFA/pretrained_models/dictionary/japanese_mfa.dict, you can now use
#                 japanese_mfa in place of dictionary paths in mfa commands.
# INFO - Saved model to f/Users/derekvawdrey/Documents/MFA/pretrained_models/dictionary/japanese_mfa.dict, you can now use
#                 japanese_mfa in place of dictionary paths in mfa commands.

# %%
# !python /Users/derekvawdrey/Workspace/School/CS479FinalProject/dataPrep/create_female_dataset.py --dataset-root /Users/derekvawdrey/Workspace/School/CS479FinalProject/dataPrep/dataset --target-sr 22050
# Out:
# Processing basic5000 (5000 files)
# Processing countersuffix26 (26 files)
# Processing loanword128 (128 files)
# Processing onomatopee300 (300 files)
# Processing precedent130 (130 files)
# Processing repeat500 (500 files)
# Processing travel1000 (1000 files)
# Processing utparaphrase512 (512 files)
# Processing voiceactress100 (100 files)

# %%
# !mfa align /Users/derekvawdrey/Workspace/School/CS479FinalProject/dataPrep/dataset/female japanese_mfa japanese_mfa /Users/derekvawdrey/Documents/MFA/aligned_output --clean
# Out:
#  INFO     Setting up corpus information...
#  INFO     Loading corpus from source files...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7,696/100  [ 0:00:00 < 0:00:00 , 2,501 it/s ]
#  INFO     Found 1 speaker across 7696 files, average number of utterances per
#           speaker: 7696.0
#  INFO     Initializing multiprocessing jobs...
#  WARNING  Number of jobs was specified as 3, but due to only having 1 speakers,
#           MFA will only use 1 jobs. Use the --single_speaker flag if you would
#           like to split utterances across jobs regardless of their speaker.
#  INFO     Normalizing text...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7,696/7,696  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Generating MFCCs...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7,696/7,696  [ 0:01:20 < 0:00:00 , 110 it/s ]115 it/s ]
#  INFO     Calculating CMVN...
#  INFO     Generating final features...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7,696/7,696  [ 0:00:02 < 0:00:00 , ? it/s ]
# ...
