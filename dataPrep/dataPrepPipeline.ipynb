# %% [markdown]
# Uses the requirements.txt in the fast-speech-2 directory

# %%
# %conda install -c conda-forge montreal-forced-aligner
# %conda install -c conda-forge --force-reinstall libsndfile soundfile

# %%
# !mfa model download acoustic japanese_mfa
# !mfa model download g2p japanese_mfa
# Out:
# Traceback (most recent call last):
#   File "c:\Users\PC\Documents\GitHub\TextToSpeechPitchAccent\.conda\lib\site-packages\soundfile.py", line 181, in <module>
#     import _soundfile_data  # ImportError if this doesn't exist
# ModuleNotFoundError: No module named '_soundfile_data'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\PC\Documents\GitHub\TextToSpeechPitchAccent\.conda\lib\site-packages\soundfile.py", line 191, in <module>
#     _snd = _ffi.dlopen(_libname)
# OSError: cannot load library 'c:\Users\PC\Documents\GitHub\TextToSpeechPitchAccent\.conda\Library\bin\sndfile.dll': error 0x7e
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\PC\Documents\GitHub\TextToSpeechPitchAccent\.conda\Scripts\mfa-script.py", line 5, in <module>
#     from montreal_forced_aligner.command_line.mfa import mfa_cli
# ...

# %%
# !mfa align \
    ./dataset \
    ./lexicon/japanese_mfa.dict \
    japanese_mfa \
    ./aligned_output \
    --clean
# Out:
#
#  Usage:
#  mfa align
#  [OPTIONS] CORPUS_DIRECTORY DICTIONARY_PATH ACOUSTIC_MODEL_PATH
#  OUTPUT_DIRECTORY
#
# ┌─ Error ─────────────────────────────────────────────────────────────────────┐
# │ Invalid value for 'CORPUS_DIRECTORY': Corpus directory does not exist.      │
# └─────────────────────────────────────────────────────────────────────────────┘
