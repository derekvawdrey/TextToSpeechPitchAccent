# %%
# %conda install torchaudio
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: c:\Users\PC\miniconda3\envs\dataDownload
#
#   added / updated specs:
#     - torchaudio
#
#
# The following NEW packages will be INSTALLED:
#
#   aom                pkgs/main/win-64::aom-3.12.1-h00a0c3c_0
#   blas               pkgs/main/win-64::blas-1.0-mkl
#   cairo              pkgs/main/win-64::cairo-1.18.4-he9e932c_0
#   dav1d              pkgs/main/win-64::dav1d-1.2.1-h2bbff1b_0
#   ffmpeg             pkgs/main/win-64::ffmpeg-6.1.1-haa678a1_5
#   filelock           pkgs/main/win-64::filelock-3.20.0-py310haa95532_0
#   fontconfig         pkgs/main/win-64::fontconfig-2.15.0-hd211d86_0
#   freetype           pkgs/main/win-64::freetype-2.13.3-h0620614_0
#   fsspec             pkgs/main/win-64::fsspec-2025.10.0-py310h4442805_0
#   gmp                pkgs/main/win-64::gmp-6.3.0-h537511b_0
#   gmpy2              pkgs/main/win-64::gmpy2-2.2.1-py310h827c3e9_0
#   graphite2          pkgs/main/win-64::graphite2-1.3.14-hd77b12b_1
#   harfbuzz           pkgs/main/win-64::harfbuzz-10.2.0-he2f9f60_1
#   icu                pkgs/main/win-64::icu-73.1-h6c2663c_0
#   intel-openmp       pkgs/main/win-64::intel-openmp-2023.1.0-h59b6b97_46320
#   jinja2             pkgs/main/win-64::jinja2-3.1.6-py310haa95532_0
#   jpeg               pkgs/main/win-64::jpeg-9f-ha349fce_0
#   lerc               pkgs/main/win-64::lerc-3.0-hd77b12b_0
#   libabseil          pkgs/main/win-64::libabseil-20250127.0-cxx17_h52369b4_0
#   libdeflate         pkgs/main/win-64::libdeflate-1.17-h2bbff1b_1
#   libglib            pkgs/main/win-64::libglib-2.84.4-hfaec014_0
#   libiconv           pkgs/main/win-64::libiconv-1.16-h2bbff1b_3
#   libogg             pkgs/main/win-64::libogg-1.3.5-h2bbff1b_1
#   libpng             pkgs/main/win-64::libpng-1.6.50-h46444df_0
#   libprotobuf        pkgs/main/win-64::libprotobuf-5.29.3-h65a231f_1
#   libtheora          pkgs/main/win-64::libtheora-1.2.0-habf309d_1
#   libtiff            pkgs/main/win-64::libtiff-4.5.1-hd77b12b_0
#   libtorch           pkgs/main/win-64::libtorch-2.5.1-cpu_mkl_h9002858_104
#   libuv              pkgs/main/win-64::libuv-1.48.0-h827c3e9_0
#   libvorbis          pkgs/main/win-64::libvorbis-1.3.7-he774522_0
#   libxml2            pkgs/main/win-64::libxml2-2.13.9-h6201b9f_0
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.4-h2bbff1b_1
#   markupsafe         pkgs/main/win-64::markupsafe-3.0.2-py310h827c3e9_0
#   mkl                pkgs/main/win-64::mkl-2023.1.0-h6b88ed4_46358
#   mkl-service        pkgs/main/win-64::mkl-service-2.4.0-py310h827c3e9_2
#   mkl_fft            pkgs/main/win-64::mkl_fft-1.3.11-py310h827c3e9_0
#   mkl_random         pkgs/main/win-64::mkl_random-1.2.8-py310hc64d2fc_0
#   mpc                pkgs/main/win-64::mpc-1.3.1-h827c3e9_0
#   mpfr               pkgs/main/win-64::mpfr-4.2.1-h56c3642_0
#   mpmath             pkgs/main/win-64::mpmath-1.3.0-py310haa95532_0
#   networkx           pkgs/main/win-64::networkx-3.4.2-py310haa95532_0
#   numpy              pkgs/main/win-64::numpy-2.0.1-py310h055cbcc_1
#   numpy-base         pkgs/main/win-64::numpy-base-2.0.1-py310h65a83cf_1
#   openjpeg           pkgs/main/win-64::openjpeg-2.5.2-hae555c5_0
#   opentelemetry-api  pkgs/main/win-64::opentelemetry-api-1.37.0-py310haa95532_0
#   pcre2              pkgs/main/win-64::pcre2-10.46-h5740b90_0
#   pixman             pkgs/main/win-64::pixman-0.46.4-h4043f72_0
#   pytorch            pkgs/main/win-64::pytorch-2.5.1-cpu_mkl_py310h0452e45_104
#   sleef              pkgs/main/win-64::sleef-3.5.1-h8cc25b3_2
#   sympy              pkgs/main/win-64::sympy-1.14.0-py310haa95532_0
#   tbb                pkgs/main/win-64::tbb-2021.8.0-h59b6b97_0
#   torchaudio         pkgs/main/win-64::torchaudio-2.5.1-py310hc64d2fc_0
#   typing-extensions  pkgs/main/win-64::typing-extensions-4.15.0-py310haa95532_0
#   zstd               pkgs/main/win-64::zstd-1.5.7-h56299aa_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   typing_extensions  conda-forge/noarch::typing_extensions~ --> pkgs/main/win-64::typing_extensions-4.15.0-py310haa95532_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pathlib, zipfile, urllib.request

root = pathlib.Path("kokoro_data")
root.mkdir(exist_ok=True)
zip_path = root / "kokoro-speech-v1_3.zip"

url = "https://github.com/kaiidams/Kokoro-Speech-Dataset/releases/download/1.3/kokoro-speech-v1_3.zip"
print(f"Downloading {url} …")
urllib.request.urlretrieve(url, zip_path)
print("Extracting …")
with zipfile.ZipFile(zip_path) as zf:
    zf.extractall(root)

print("Done.")
# Out:
# Downloading https://github.com/kaiidams/Kokoro-Speech-Dataset/releases/download/1.3/kokoro-speech-v1_3.zip …
# Extracting …
# Done.

# %%
import os
import json
import torchaudio
import torch

# Utility print for notebook
def err_print(*args, **kwargs):
    print(*args, **kwargs)

# --- Functions from original script ---
def read_params_list(data_dir, size):
    index_file = os.path.join(data_dir, 'index.json')
    if not os.path.exists(index_file):
        raise FileNotFoundError("`data/index.json` not found. Please download it from the project page.")

    with open(index_file, encoding="utf-8") as f:
        params_list = json.load(f)

    return [
        params for params in params_list
        if (size == 'xlarge') or (size in params['sizes'].split())
    ]


def check_data_directory(data_dir, params_list):
    isok = True
    for params in params_list:
        id_ = params['id']
        audio_dir = os.path.join(data_dir, f'{id_}')
        if not os.path.isdir(audio_dir):
            err_print(f"Missing: `{audio_dir}`")
            isok = False
    if isok:
        err_print("✅ All audio directories exist.")
    return isok


def dump_script(data_dir, params_list):
    err_print('\n⚙️ Run these commands to download missing archives manually:\n')
    print(f'cd {data_dir}')
    for params in params_list:
        print(f'curl -LO {params["archive_url"]}')
    for params in params_list:
        archive_url = params['archive_url']
        archive_file = os.path.basename(archive_url)
        id_ = params['id']
        print(f"unzip {archive_file} -d {id_}")


def extract_wav_files(data_dir, params_list, clip_format, sample_rate, output_dir):
    clip_dir = 'wavs'
    clip_ext = clip_format
    os.makedirs(os.path.join(output_dir, clip_dir), exist_ok=True)
    max_int16 = torch.iinfo(torch.int16).max

    for params in params_list:
        id_ = params['id']
        metadata_file = os.path.join(data_dir, f'{id_}.metadata.txt')
        audio_dir = os.path.join(data_dir, f'{id_}')
        with open(metadata_file, 'rt', encoding="utf-8") as metadata_f:
            current_file = None
            current_audio = None
            for line in metadata_f:
                parts = line.rstrip('\r\n').split('|')
                id_, audio_file, audio_start, audio_end, _, _ = parts
                audio_start, audio_end = int(audio_start), int(audio_end)
                if current_file != audio_file:
                    file = os.path.join(audio_dir, audio_file)
                    err_print(f'Reading {file}...')
                    y, sr = torchaudio.load(file)
                    assert len(y.shape) == 2 and y.shape[0] == 1
                    assert y.dtype == torch.float32
                    assert sr == sample_rate
                    y = (y * max_int16 / torch.max(torch.abs(y))).to(torch.int16)
                    current_file = audio_file
                    current_audio = y
                output_file = os.path.join(output_dir, clip_dir, f'{id_}.{clip_ext}')
                y = current_audio[:, audio_start:audio_end]
                torchaudio.save(output_file, y, sample_rate)


def write_metafile(data_dir, params_list, output_dir):
    metadata_outfile = os.path.join(output_dir, 'metadata.csv')
    with open(metadata_outfile, 'wt', encoding="utf-8") as metadata_f:
        for params in params_list:
            id_ = params['id']
            metadata_file = os.path.join(data_dir, f'{id_}.metadata.txt')
            with open(metadata_file, 'rt', encoding="utf-8") as transcript_f:
                for line in transcript_f:
                    parts = line.rstrip('\r\n').split('|')
                    id_, _, _, _, text, voca = parts
                    metadata_f.write(f'{id_}|{text}|{voca}\n')
    err_print(f"✅ Metadata written to {metadata_outfile}")

# --- Notebook main logic (instead of argparse) ---
data_dir = 'kokoro_data'           # @param ["data"] {allow-input: true}
output_dir = 'output'       # @param ["output"] {allow-input: true}
size = 'large'               # @param ["tiny", "small", "large", "xlarge"]
clip_format = 'wav'         # @param ["wav", "flac", "mp3", "ogg"]
sample_rate = 22050         # @param {type:"integer"}

# --- Run processing ---
params_list = read_params_list(data_dir, size)
if not params_list:
    raise ValueError(f"No matching params found for size '{size}'.")

if not check_data_directory(data_dir, params_list):
    dump_script(data_dir, params_list)
else:
    extract_wav_files(data_dir, params_list, clip_format, sample_rate, output_dir)
    write_metafile(data_dir, params_list, output_dir)
# Out:
# ✅ All audio directories exist.
# Reading kokoro_data\meian-by-soseki-natsume\meian_001_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_002_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_003_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_004_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_005_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_006_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_007_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_008_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_009_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_010_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_011_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_012_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_013_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_014_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_015_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_016_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_017_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_018_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_019_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_020_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_021_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_022_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_023_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_024_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_025_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_026_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_027_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_028_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_029_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_030_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_031_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_032_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_033_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_034_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_035_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_036_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_037_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_038_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_039_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_040_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_041_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_042_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_043_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_044_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_045_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_046_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_047_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_048_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_049_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_050_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_051_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_052_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_053_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_054_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_055_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_056_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_057_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_058_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_059_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_060_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_061_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_062_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_063_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_064_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_065_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_066_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_067_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_068_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_069_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_070_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_071_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_072_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_073_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_074_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_075_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_076_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_077_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_078_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_079_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_080_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_081_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_082_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_083_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_084_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_085_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_086_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_087_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_088_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_089_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_090_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_091_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_092_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_093_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_094_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_095_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_096_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_097_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_098_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_099_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_100_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_101_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_102_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_103_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_104_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_105_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_106_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_107_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_108_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_109_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_110_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_111_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_112_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_113_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_114_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_115_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_116_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_117_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_118_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_119_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_120_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_121_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_122_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_123_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_124_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_125_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_126_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_127_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_128_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_129_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_130_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_131_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_132_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_133_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_134_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_135_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_136_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_137_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_138_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_139_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_140_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_141_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_142_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_143_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_144_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_145_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_146_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_147_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_148_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_149_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_150_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_151_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_152_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_153_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_154_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_155_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_156_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_157_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_158_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_159_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_160_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_161_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_162_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_163_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_164_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_165_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_166_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_167_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_168_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_169_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_170_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_171_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_172_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_173_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_174_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_175_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_176_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_177_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_178_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_179_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_180_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_181_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_182_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_183_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_184_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_185_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_186_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_187_natsume_64kb.mp3...
# Reading kokoro_data\meian-by-soseki-natsume\meian_188_natsume_64kb.mp3...
# Reading kokoro_data\umareizuru-nayami-by-takeo-arishima\umareizurunayami_1_arishima_64kb.mp3...
# Reading kokoro_data\umareizuru-nayami-by-takeo-arishima\umareizurunayami_2_arishima_64kb.mp3...
# Reading kokoro_data\umareizuru-nayami-by-takeo-arishima\umareizurunayami_3_arishima_64kb.mp3...
# Reading kokoro_data\umareizuru-nayami-by-takeo-arishima\umareizurunayami_4_arishima_64kb.mp3...
# Reading kokoro_data\umareizuru-nayami-by-takeo-arishima\umareizurunayami_5_arishima_64kb.mp3...
# Reading kokoro_data\umareizuru-nayami-by-takeo-arishima\umareizurunayami_6_arishima_64kb.mp3...
# Reading kokoro_data\umareizuru-nayami-by-takeo-arishima\umareizurunayami_7_arishima_64kb.mp3...
# Reading kokoro_data\umareizuru-nayami-by-takeo-arishima\umareizurunayami_8_arishima_64kb.mp3...
# Reading kokoro_data\umareizuru-nayami-by-takeo-arishima\umareizurunayami_9_arishima_64kb.mp3...
# Reading kokoro_data\futon-by-katai-tayama\futon_01_tayama_64kb.mp3...
# Reading kokoro_data\futon-by-katai-tayama\futon_02_tayama_64kb.mp3...
# Reading kokoro_data\futon-by-katai-tayama\futon_03_tayama_64kb.mp3...
# Reading kokoro_data\futon-by-katai-tayama\futon_04_tayama_64kb.mp3...
# Reading kokoro_data\futon-by-katai-tayama\futon_05_tayama_64kb.mp3...
# Reading kokoro_data\futon-by-katai-tayama\futon_06_tayama_64kb.mp3...
# Reading kokoro_data\futon-by-katai-tayama\futon_07_tayama_64kb.mp3...
# Reading kokoro_data\futon-by-katai-tayama\futon_08_tayama_64kb.mp3...
# Reading kokoro_data\futon-by-katai-tayama\futon_09_tayama_64kb.mp3...
# Reading kokoro_data\futon-by-katai-tayama\futon_10_tayama_64kb.mp3...
# Reading kokoro_data\futon-by-katai-tayama\futon_11_tayama_64kb.mp3...
# ✅ Metadata written to output\metadata.csv

# %% [markdown]
# # To download the audio files if missing, just paste in the archive urls for each individual file

# %%
import pathlib, zipfile, urllib.request

root = pathlib.Path("kokoro_data")
root.mkdir(exist_ok=True)

sources = [
    ("http://www.archive.org/download/kusamakura_1311_librivox/kusamakura_1311_librivox_64kb_mp3.zip",
     "kusamakura-by-soseki-natsume"),
    ("http://www.archive.org/download/gan_1311_librivox/gan_1311_librivox_64kb_mp3.zip",
     "gan-by-ogai-mori"),
    ("http://www.archive.org/download/umareizuru_nayami_ez_1302/umareizuru_nayami_ez_1302_64kb_mp3.zip",
     "umareizuru-nayami-by-takeo-arishima"),
    ("http://www.archive.org/download/futon_ek_1303_librivox/futon_ek_1303_librivox_64kb_mp3.zip",
     "futon-by-katai-tayama"),
    ("http://www.archive.org/download/meian_1403_librivox/meian_1403_librivox_64kb_mp3.zip",
     "meian-by-soseki-natsume"),
]

for url, folder_name in sources:
    zip_path = root / pathlib.Path(url).name
    target_dir = root / folder_name
    print(f"Downloading {url} …")
    urllib.request.urlretrieve(url, zip_path)
    print(f"Extracting to {target_dir} …")
    target_dir.mkdir(exist_ok=True)
    with zipfile.ZipFile(zip_path) as zf:
        zf.extractall(target_dir)
    print("Done.\n")
# Out:
# Downloading http://www.archive.org/download/meian_1403_librivox/meian_1403_librivox_64kb_mp3.zip …
# Extracting to kokoro_data\meian-by-soseki-natsume …
# Done.

# %% [markdown]
# # Process into needed files
#
# We are making lab files for the output and preprocessing

# %%
from pathlib import Path
import csv

out_dir = Path("./output")
wav_dir = out_dir / "wavs"

with (out_dir / "metadata.csv").open(encoding="utf8") as f:
    reader = csv.reader(f, delimiter="|")
    for utt_id, orth, *_ in reader:
        (wav_dir / f"{utt_id}.lab").write_text(orth.strip(), encoding="utf8")
