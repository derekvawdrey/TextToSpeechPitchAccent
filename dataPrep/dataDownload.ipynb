# %%
# %conda install torchaudio
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: c:\Users\PC\Documents\GitHub\TextToSpeechPitchAccent\.conda
#
#   added / updated specs:
#     - torchaudio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.12.1                 |       h00a0c3c_0         5.5 MB
#     blas-1.0                   |              mkl           6 KB
#     cairo-1.18.4               |       he9e932c_0         637 KB
#     dav1d-1.2.1                |       h2bbff1b_0         672 KB
#     ffmpeg-6.1.1               |       haa678a1_5        10.4 MB
#     filelock-3.20.0            |  py310haa95532_0          33 KB
#     fontconfig-2.15.0          |       hd211d86_0         206 KB
#     freetype-2.13.3            |       h0620614_0         554 KB
#     fsspec-2025.10.0           |  py310h4442805_0         525 KB
#     gmp-6.3.0                  |       h537511b_0         330 KB
#     gmpy2-2.2.1                |  py310h827c3e9_0         205 KB
#     graphite2-1.3.14           |       hd77b12b_1          91 KB
#     harfbuzz-10.2.0            |       he2f9f60_1         1.2 MB
#     icu-73.1                   |       h6c2663c_0        29.5 MB
#     intel-openmp-2023.1.0      |   h59b6b97_46320         2.7 MB
#     jinja2-3.1.6               |  py310haa95532_0         279 KB
#     jpeg-9f                    |       ha349fce_0         302 KB
#     lerc-3.0                   |       hd77b12b_0         120 KB
#     libabseil-20250127.0       | cxx17_h52369b4_0         1.9 MB
#     libdeflate-1.17            |       h2bbff1b_1         153 KB
#     libglib-2.84.4             |       hfaec014_0         1.4 MB
#     libogg-1.3.5               |       h2bbff1b_1          33 KB
#     libpng-1.6.50              |       h46444df_0         237 KB
#     libprotobuf-5.29.3         |       h65a231f_1         7.5 MB
#     libtheora-1.2.0            |       habf309d_1         151 KB
#     libtiff-4.5.1              |       hd77b12b_0         1.1 MB
#     libtorch-2.5.1             |cpu_mkl_h9002858_104        35.7 MB
#     libuv-1.48.0               |       h827c3e9_0         322 KB
#     libvorbis-1.3.7            |       he774522_0         202 KB
#     markupsafe-3.0.2           |  py310h827c3e9_0          36 KB
#     mkl-2023.1.0               |   h6b88ed4_46358       155.9 MB
#     mkl-service-2.4.0          |  py310h827c3e9_2          66 KB
#     mkl_fft-1.3.11             |  py310h827c3e9_0         168 KB
#     mkl_random-1.2.8           |  py310hc64d2fc_0         257 KB
#     mpc-1.3.1                  |       h827c3e9_0          85 KB
#     mpfr-4.2.1                 |       h56c3642_0         266 KB
#     mpmath-1.3.0               |  py310haa95532_0         834 KB
#     networkx-3.4.2             |  py310haa95532_0         2.5 MB
#     numpy-2.0.1                |  py310h055cbcc_1          11 KB
#     numpy-base-2.0.1           |  py310h65a83cf_1         9.1 MB
#     openjpeg-2.5.2             |       hae555c5_0         268 KB
#     opentelemetry-api-1.37.0   |  py310haa95532_0          80 KB
#     pixman-0.46.4              |       h4043f72_0         257 KB
#     pytorch-2.5.1              |cpu_mkl_py310h0452e45_104        35.1 MB
#     sleef-3.5.1                |       h8cc25b3_2         996 KB
#     sympy-1.14.0               |  py310haa95532_0        11.5 MB
#     tbb-2021.8.0               |       h59b6b97_0         149 KB
#     torchaudio-2.5.1           |  py310hc64d2fc_0         4.8 MB
#     typing-extensions-4.15.0   |  py310haa95532_0          12 KB
#     typing_extensions-4.15.0   |  py310haa95532_0          79 KB
#     ------------------------------------------------------------
#                                            Total:       324.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   aom                pkgs/main/win-64::aom-3.12.1-h00a0c3c_0
#   blas               pkgs/main/win-64::blas-1.0-mkl
#   cairo              pkgs/main/win-64::cairo-1.18.4-he9e932c_0
#   dav1d              pkgs/main/win-64::dav1d-1.2.1-h2bbff1b_0
#   ffmpeg             pkgs/main/win-64::ffmpeg-6.1.1-haa678a1_5
#   filelock           pkgs/main/win-64::filelock-3.20.0-py310haa95532_0
#   fontconfig         pkgs/main/win-64::fontconfig-2.15.0-hd211d86_0
#   freetype           pkgs/main/win-64::freetype-2.13.3-h0620614_0
#   fsspec             pkgs/main/win-64::fsspec-2025.10.0-py310h4442805_0
#   gmp                pkgs/main/win-64::gmp-6.3.0-h537511b_0
#   gmpy2              pkgs/main/win-64::gmpy2-2.2.1-py310h827c3e9_0
#   graphite2          pkgs/main/win-64::graphite2-1.3.14-hd77b12b_1
#   harfbuzz           pkgs/main/win-64::harfbuzz-10.2.0-he2f9f60_1
#   icu                pkgs/main/win-64::icu-73.1-h6c2663c_0
#   intel-openmp       pkgs/main/win-64::intel-openmp-2023.1.0-h59b6b97_46320
#   jinja2             pkgs/main/win-64::jinja2-3.1.6-py310haa95532_0
#   jpeg               pkgs/main/win-64::jpeg-9f-ha349fce_0
#   lerc               pkgs/main/win-64::lerc-3.0-hd77b12b_0
#   libabseil          pkgs/main/win-64::libabseil-20250127.0-cxx17_h52369b4_0
#   libdeflate         pkgs/main/win-64::libdeflate-1.17-h2bbff1b_1
#   libglib            pkgs/main/win-64::libglib-2.84.4-hfaec014_0
#   libiconv           pkgs/main/win-64::libiconv-1.16-h2bbff1b_3
#   libogg             pkgs/main/win-64::libogg-1.3.5-h2bbff1b_1
#   libpng             pkgs/main/win-64::libpng-1.6.50-h46444df_0
#   libprotobuf        pkgs/main/win-64::libprotobuf-5.29.3-h65a231f_1
#   libtheora          pkgs/main/win-64::libtheora-1.2.0-habf309d_1
#   libtiff            pkgs/main/win-64::libtiff-4.5.1-hd77b12b_0
#   libtorch           pkgs/main/win-64::libtorch-2.5.1-cpu_mkl_h9002858_104
#   libuv              pkgs/main/win-64::libuv-1.48.0-h827c3e9_0
#   libvorbis          pkgs/main/win-64::libvorbis-1.3.7-he774522_0
#   libxml2            pkgs/main/win-64::libxml2-2.13.9-h6201b9f_0
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.4-h2bbff1b_1
#   markupsafe         pkgs/main/win-64::markupsafe-3.0.2-py310h827c3e9_0
#   mkl                pkgs/main/win-64::mkl-2023.1.0-h6b88ed4_46358
#   mkl-service        pkgs/main/win-64::mkl-service-2.4.0-py310h827c3e9_2
#   mkl_fft            pkgs/main/win-64::mkl_fft-1.3.11-py310h827c3e9_0
#   mkl_random         pkgs/main/win-64::mkl_random-1.2.8-py310hc64d2fc_0
#   mpc                pkgs/main/win-64::mpc-1.3.1-h827c3e9_0
#   mpfr               pkgs/main/win-64::mpfr-4.2.1-h56c3642_0
#   mpmath             pkgs/main/win-64::mpmath-1.3.0-py310haa95532_0
#   networkx           pkgs/main/win-64::networkx-3.4.2-py310haa95532_0
#   numpy              pkgs/main/win-64::numpy-2.0.1-py310h055cbcc_1
#   numpy-base         pkgs/main/win-64::numpy-base-2.0.1-py310h65a83cf_1
#   openjpeg           pkgs/main/win-64::openjpeg-2.5.2-hae555c5_0
#   opentelemetry-api  pkgs/main/win-64::opentelemetry-api-1.37.0-py310haa95532_0
#   pcre2              pkgs/main/win-64::pcre2-10.46-h5740b90_0
#   pixman             pkgs/main/win-64::pixman-0.46.4-h4043f72_0
#   pytorch            pkgs/main/win-64::pytorch-2.5.1-cpu_mkl_py310h0452e45_104
#   sleef              pkgs/main/win-64::sleef-3.5.1-h8cc25b3_2
#   sympy              pkgs/main/win-64::sympy-1.14.0-py310haa95532_0
#   tbb                pkgs/main/win-64::tbb-2021.8.0-h59b6b97_0
#   torchaudio         pkgs/main/win-64::torchaudio-2.5.1-py310hc64d2fc_0
#   typing-extensions  pkgs/main/win-64::typing-extensions-4.15.0-py310haa95532_0
#   zstd               pkgs/main/win-64::zstd-1.5.7-h56299aa_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   typing_extensions  conda-forge/noarch::typing_extensions~ --> pkgs/main/win-64::typing_extensions-4.15.0-py310haa95532_0
#
#
#
# Downloading and Extracting Packages: ...working...
# mkl-2023.1.0         | 155.9 MB  |            |   0%
#
# libtorch-2.5.1       | 35.7 MB   |            |   0%
#
#
# pytorch-2.5.1        | 35.1 MB   |            |   0%
#
#
#
# icu-73.1             | 29.5 MB   |            |   0%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   |            |   0%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   |            |   0%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    |            |   0%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    |            |   0%
#
#
#
#
#
#
#
#
# aom-3.12.1           | 5.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 4.8 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 2.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20250127.0 | 1.9 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.4       | 1.4 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.5.1          | 996 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 834 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dav1d-1.2.1          | 672 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libtorch-2.5.1       | 35.7 MB   |            |   0%
#
#
#
# icu-73.1             | 29.5 MB   |            |   0%
# mkl-2023.1.0         | 155.9 MB  |            |   0%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   |            |   0%
#
# libtorch-2.5.1       | 35.7 MB   | 4          |   5%
#
#
#
# icu-73.1             | 29.5 MB   | 2          |   2%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | 2          |   2%
#
#
# pytorch-2.5.1        | 35.1 MB   |            |   0%
#
# libtorch-2.5.1       | 35.7 MB   | 7          |   7%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | 4          |   4%
# mkl-2023.1.0         | 155.9 MB  |            |   0%
#
#
#
# icu-73.1             | 29.5 MB   | 3          |   4%
#
# libtorch-2.5.1       | 35.7 MB   | #5         |  15%
# mkl-2023.1.0         | 155.9 MB  |            |   1%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | 8          |   8%
#
#
#
# icu-73.1             | 29.5 MB   | 7          |   7%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | #          |  10%
#
# libtorch-2.5.1       | 35.7 MB   | #9         |  20%
#
#
#
# icu-73.1             | 29.5 MB   | 9          |   9%
# mkl-2023.1.0         | 155.9 MB  |            |   1%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | #6         |  17%
#
# libtorch-2.5.1       | 35.7 MB   | ##4        |  24%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | ##1        |  22%
#
#
#
# icu-73.1             | 29.5 MB   | #3         |  14%
# mkl-2023.1.0         | 155.9 MB  | 1          |   1%
#
# libtorch-2.5.1       | 35.7 MB   | ##8        |  28%
# mkl-2023.1.0         | 155.9 MB  | 2          |   2%
#
#
#
# icu-73.1             | 29.5 MB   | #9         |  20%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | ##7        |  28%
#
# libtorch-2.5.1       | 35.7 MB   | ###1       |  32%
# mkl-2023.1.0         | 155.9 MB  | 2          |   3%
#
#
#
# icu-73.1             | 29.5 MB   | ##3        |  24%
#
#
# pytorch-2.5.1        | 35.1 MB   |            |   0%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | ###4       |  34%
#
# libtorch-2.5.1       | 35.7 MB   | ###4       |  35%
#
#
#
# icu-73.1             | 29.5 MB   | ##7        |  27%
#
#
# pytorch-2.5.1        | 35.1 MB   | 1          |   1%
# mkl-2023.1.0         | 155.9 MB  | 3          |   3%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | ###9       |  39%
#
#
# pytorch-2.5.1        | 35.1 MB   | 2          |   2%
#
# libtorch-2.5.1       | 35.7 MB   | ###7       |  38%
#
#
#
# icu-73.1             | 29.5 MB   | ###        |  31%
# mkl-2023.1.0         | 155.9 MB  | 3          |   4%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | ####3      |  43%
#
#
# pytorch-2.5.1        | 35.1 MB   | 2          |   3%
#
# libtorch-2.5.1       | 35.7 MB   | ####       |  40%
#
#
#
# icu-73.1             | 29.5 MB   | ###3       |  34%
# mkl-2023.1.0         | 155.9 MB  | 3          |   4%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | #####      |  50%
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  43%
#
#
#
# icu-73.1             | 29.5 MB   | ###6       |  36%
#
#
# pytorch-2.5.1        | 35.1 MB   | 4          |   4%
# mkl-2023.1.0         | 155.9 MB  | 4          |   4%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | #####6     |  56%
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  45%
#
#
#
# icu-73.1             | 29.5 MB   | ###8       |  39%
#
#
# pytorch-2.5.1        | 35.1 MB   | 5          |   6%
# mkl-2023.1.0         | 155.9 MB  | 5          |   5%
#
# libtorch-2.5.1       | 35.7 MB   | ####7      |  47%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | ######1    |  61%
#
#
#
# icu-73.1             | 29.5 MB   | ####2      |  42%
#
#
# pytorch-2.5.1        | 35.1 MB   | 7          |   7%
# mkl-2023.1.0         | 155.9 MB  | 5          |   5%
#
# libtorch-2.5.1       | 35.7 MB   | ####9      |  49%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | ######5    |  65%
#
#
#
# icu-73.1             | 29.5 MB   | ####6      |  46%
#
#
# pytorch-2.5.1        | 35.1 MB   | 8          |   8%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | ######9    |  70%
# mkl-2023.1.0         | 155.9 MB  | 5          |   6%
#
# libtorch-2.5.1       | 35.7 MB   | #####1     |  52%
#
#
#
# icu-73.1             | 29.5 MB   | ####8      |  49%
#
#
# pytorch-2.5.1        | 35.1 MB   | 9          |  10%
# mkl-2023.1.0         | 155.9 MB  | 6          |   6%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | #######3   |  74%
#
# libtorch-2.5.1       | 35.7 MB   | #####3     |  54%
#
#
#
# icu-73.1             | 29.5 MB   | #####2     |  53%
# mkl-2023.1.0         | 155.9 MB  | 6          |   7%
#
#
# pytorch-2.5.1        | 35.1 MB   | #          |  11%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | #######7   |  78%
#
# libtorch-2.5.1       | 35.7 MB   | #####5     |  56%
#
#
#
# icu-73.1             | 29.5 MB   | #####5     |  56%
# mkl-2023.1.0         | 155.9 MB  | 7          |   7%
#
#
# pytorch-2.5.1        | 35.1 MB   | #1         |  12%
#
# libtorch-2.5.1       | 35.7 MB   | #####7     |  58%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | ########1  |  82%
#
#
#
# icu-73.1             | 29.5 MB   | #####8     |  59%
#
#
# pytorch-2.5.1        | 35.1 MB   | #2         |  13%
# mkl-2023.1.0         | 155.9 MB  | 7          |   8%
#
# libtorch-2.5.1       | 35.7 MB   | #####9     |  60%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | #########1 |  92%
#
#
#
# icu-73.1             | 29.5 MB   | ######2    |  62%
# mkl-2023.1.0         | 155.9 MB  | 8          |   8%
#
#
# pytorch-2.5.1        | 35.1 MB   | #3         |  14%
#
# libtorch-2.5.1       | 35.7 MB   | ######1    |  61%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | #########5 |  96%
#
#
#
# icu-73.1             | 29.5 MB   | ######4    |  65%
#
#
# pytorch-2.5.1        | 35.1 MB   | #4         |  15%
#
# libtorch-2.5.1       | 35.7 MB   | ######3    |  64%
# mkl-2023.1.0         | 155.9 MB  | 8          |   9%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | ########## | 100%
#
#
#
# icu-73.1             | 29.5 MB   | #######1   |  71%
#
#
# pytorch-2.5.1        | 35.1 MB   | #5         |  16%
#
# libtorch-2.5.1       | 35.7 MB   | ######5    |  66%
# mkl-2023.1.0         | 155.9 MB  | 9          |  10%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   |            |   0%
#
#
# pytorch-2.5.1        | 35.1 MB   | #6         |  17%
#
# libtorch-2.5.1       | 35.7 MB   | ######7    |  68%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | 1          |   2%
# mkl-2023.1.0         | 155.9 MB  | #          |  10%
#
#
# pytorch-2.5.1        | 35.1 MB   | #7         |  18%
#
#
#
# icu-73.1             | 29.5 MB   | #######4   |  75%
#
# libtorch-2.5.1       | 35.7 MB   | #######    |  70%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | 7          |   8%
# mkl-2023.1.0         | 155.9 MB  | #          |  11%
#
#
#
# icu-73.1             | 29.5 MB   | #######7   |  78%
#
#
# pytorch-2.5.1        | 35.1 MB   | #8         |  19%
#
# libtorch-2.5.1       | 35.7 MB   | #######2   |  73%
# mkl-2023.1.0         | 155.9 MB  | #          |  11%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | #1         |  11%
#
#
#
# icu-73.1             | 29.5 MB   | ########   |  81%
#
#
# pytorch-2.5.1        | 35.1 MB   | #9         |  20%
#
# libtorch-2.5.1       | 35.7 MB   | #######5   |  75%
# mkl-2023.1.0         | 155.9 MB  | #1         |  11%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | #9         |  20%
#
#
#
# icu-73.1             | 29.5 MB   | ########3  |  84%
#
#
# pytorch-2.5.1        | 35.1 MB   | ##         |  20%
#
# libtorch-2.5.1       | 35.7 MB   | #######7   |  77%
# mkl-2023.1.0         | 155.9 MB  | #1         |  12%
#
#
#
# icu-73.1             | 29.5 MB   | ########6  |  86%
#
#
# pytorch-2.5.1        | 35.1 MB   | ##1        |  21%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | ##4        |  24%
#
# libtorch-2.5.1       | 35.7 MB   | #######9   |  79%
# mkl-2023.1.0         | 155.9 MB  | #2         |  13%
#
#
#
# icu-73.1             | 29.5 MB   | #########  |  90%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | ###1       |  32%
#
# libtorch-2.5.1       | 35.7 MB   | ########1  |  81%
#
#
# pytorch-2.5.1        | 35.1 MB   | ##2        |  22%
# mkl-2023.1.0         | 155.9 MB  | #3         |  13%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | ###6       |  37%
#
#
#
# icu-73.1             | 29.5 MB   | #########3 |  93%
#
# libtorch-2.5.1       | 35.7 MB   | ########2  |  83%
#
#
# pytorch-2.5.1        | 35.1 MB   | ##3        |  24%
# mkl-2023.1.0         | 155.9 MB  | #3         |  14%
#
#
#
# icu-73.1             | 29.5 MB   | #########6 |  96%
#
# libtorch-2.5.1       | 35.7 MB   | ########5  |  85%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | ####1      |  42%
# mkl-2023.1.0         | 155.9 MB  | #4         |  14%
#
#
# pytorch-2.5.1        | 35.1 MB   | ##4        |  24%
#
#
#
# icu-73.1             | 29.5 MB   | #########9 | 100%
#
# libtorch-2.5.1       | 35.7 MB   | ########7  |  87%
#
#
#
# icu-73.1             | 29.5 MB   | ########## | 100%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | #####3     |  53%
# mkl-2023.1.0         | 155.9 MB  | #4         |  15%
#
#
# pytorch-2.5.1        | 35.1 MB   | ##5        |  26%
#
# libtorch-2.5.1       | 35.7 MB   | ########9  |  90%
# mkl-2023.1.0         | 155.9 MB  | #5         |  16%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | #####9     |  60%
#
#
# pytorch-2.5.1        | 35.1 MB   | ##6        |  27%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    |            |   0%
#
# libtorch-2.5.1       | 35.7 MB   | #########2 |  92%
#
#
# pytorch-2.5.1        | 35.1 MB   | ##7        |  28%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | 5          |   5%
# mkl-2023.1.0         | 155.9 MB  | #6         |  16%
#
# libtorch-2.5.1       | 35.7 MB   | #########4 |  94%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | ######6    |  66%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | 8          |   9%
#
#
# pytorch-2.5.1        | 35.1 MB   | ##8        |  29%
#
# libtorch-2.5.1       | 35.7 MB   | #########6 |  97%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | #######1   |  72%
# mkl-2023.1.0         | 155.9 MB  | #6         |  17%
#
#
# pytorch-2.5.1        | 35.1 MB   | ##9        |  30%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | #1         |  12%
#
# libtorch-2.5.1       | 35.7 MB   | #########8 |  99%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | #######6   |  77%
# mkl-2023.1.0         | 155.9 MB  | #7         |  17%
#
#
# pytorch-2.5.1        | 35.1 MB   | ###1       |  31%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | ##5        |  26%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | ########7  |  87%
# mkl-2023.1.0         | 155.9 MB  | #8         |  19%
#
# libtorch-2.5.1       | 35.7 MB   | ########## | 100%
#
#
# pytorch-2.5.1        | 35.1 MB   | ###2       |  32%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | ####       |  41%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    |            |   0%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | #########4 |  94%
#
#
# pytorch-2.5.1        | 35.1 MB   | ###3       |  33%
# mkl-2023.1.0         | 155.9 MB  | #9         |  19%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | 5          |   5%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | #####      |  50%
#
#
# pytorch-2.5.1        | 35.1 MB   | ###4       |  34%
#
#
#
# icu-73.1             | 29.5 MB   | ########## | 100%
# mkl-2023.1.0         | 155.9 MB  | #9         |  20%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | #5         |  16%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | ######2    |  62%
#
#
# pytorch-2.5.1        | 35.1 MB   | ###5       |  36%
# mkl-2023.1.0         | 155.9 MB  | ##         |  21%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | ########## | 100%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | ##5        |  25%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | #######2   |  72%
#
#
# pytorch-2.5.1        | 35.1 MB   | ###6       |  37%
# mkl-2023.1.0         | 155.9 MB  | ##1        |  21%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | ###2       |  33%
#
#
#
#
#
#
#
#
# aom-3.12.1           | 5.5 MB    |            |   0%
#
#
# pytorch-2.5.1        | 35.1 MB   | ###7       |  38%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | ########   |  81%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | ####       |  40%
# mkl-2023.1.0         | 155.9 MB  | ##2        |  22%
#
#
#
#
#
#
#
#
# aom-3.12.1           | 5.5 MB    | 5          |   6%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | ########9  |  90%
#
#
# pytorch-2.5.1        | 35.1 MB   | ###9       |  39%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | ####6      |  47%
#
#
#
#
#
#
#
#
# aom-3.12.1           | 5.5 MB    | ##2        |  23%
# mkl-2023.1.0         | 155.9 MB  | ##2        |  23%
#
#
# pytorch-2.5.1        | 35.1 MB   | ####       |  40%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | ########## | 100%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | ########## | 100%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | #####4     |  54%
#
#
#
#
#
#
#
#
# aom-3.12.1           | 5.5 MB    | ###2       |  32%
# mkl-2023.1.0         | 155.9 MB  | ##4        |  24%
#
#
# pytorch-2.5.1        | 35.1 MB   | ####1      |  42%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | ######4    |  64%
#
#
#
#
#
#
#
#
# aom-3.12.1           | 5.5 MB    | ####8      |  48%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | #######2   |  72%
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 4.8 MB    |            |   0%
#
#
# pytorch-2.5.1        | 35.1 MB   | ####2      |  43%
# mkl-2023.1.0         | 155.9 MB  | ##5        |  25%
#
#
#
#
#
# ffmpeg-6.1.1         | 10.4 MB   | ########## | 100%
#
#
#
#
#
#
#
#
# aom-3.12.1           | 5.5 MB    | #####9     |  60%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | ########   |  80%
#
#
# pytorch-2.5.1        | 35.1 MB   | ####3      |  44%
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 4.8 MB    | #4         |  14%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | ########7  |  88%
# mkl-2023.1.0         | 155.9 MB  | ##5        |  26%
#
#
# pytorch-2.5.1        | 35.1 MB   | ####4      |  45%
#
#
#
#
#
#
#
#
# aom-3.12.1           | 5.5 MB    | #######    |  70%
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 4.8 MB    | ##8        |  28%
#
#
# pytorch-2.5.1        | 35.1 MB   | ####5      |  46%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | #########6 |  96%
#
#
#
#
#
#
#
#
# aom-3.12.1           | 5.5 MB    | ########   |  80%
# mkl-2023.1.0         | 155.9 MB  | ##6        |  27%
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 4.8 MB    | ###7       |  38%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | ########## | 100%
#
#
# pytorch-2.5.1        | 35.1 MB   | ####7      |  47%
#
#
#
#
#
#
#
#
# aom-3.12.1           | 5.5 MB    | #########4 |  94%
# mkl-2023.1.0         | 155.9 MB  | ##7        |  28%
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 4.8 MB    | ######1    |  62%
#
#
#
#
#
#
#
#
# aom-3.12.1           | 5.5 MB    | ########## | 100%
#
#
# pytorch-2.5.1        | 35.1 MB   | ####8      |  49%
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    |            |   1%
# mkl-2023.1.0         | 155.9 MB  | ##9        |  29%
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 4.8 MB    | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 2.5 MB    |            |   1%
#
#
# pytorch-2.5.1        | 35.1 MB   | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 2.5 MB    | #1         |  11%
# mkl-2023.1.0         | 155.9 MB  | ##9        |  30%
#
#
# pytorch-2.5.1        | 35.1 MB   | #####1     |  51%
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | ###3       |  34%
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 4.8 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 2.5 MB    | ####6      |  47%
# mkl-2023.1.0         | 155.9 MB  | ###        |  31%
#
#
# pytorch-2.5.1        | 35.1 MB   | #####2     |  52%
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | #####1     |  52%
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 2.5 MB    | ######5    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20250127.0 | 1.9 MB    |            |   1%
#
#
# pytorch-2.5.1        | 35.1 MB   | #####3     |  54%
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | #######    |  71%
# mkl-2023.1.0         | 155.9 MB  | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20250127.0 | 1.9 MB    | ###7       |  38%
#
#
# pytorch-2.5.1        | 35.1 MB   | #####5     |  55%
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 2.5 MB    | ########3  |  83%
# mkl-2023.1.0         | 155.9 MB  | ###2       |  33%
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20250127.0 | 1.9 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 2.5 MB    | ########## | 100%
#
#
# pytorch-2.5.1        | 35.1 MB   | #####7     |  57%
# mkl-2023.1.0         | 155.9 MB  | ###4       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.4       | 1.4 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | 1          |   1%
#
#
# pytorch-2.5.1        | 35.1 MB   | #####9     |  59%
# mkl-2023.1.0         | 155.9 MB  | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.4       | 1.4 MB    | ###1       |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | ####8      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | ##9        |  29%
#
#
# pytorch-2.5.1        | 35.1 MB   | ######     |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.4       | 1.4 MB    | ######6    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | ######3    |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | #########2 |  93%
# mkl-2023.1.0         | 155.9 MB  | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | ########## | 100%
#
#
# pytorch-2.5.1        | 35.1 MB   | ######2    |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.4       | 1.4 MB    | ########## | 100%
# mkl-2023.1.0         | 155.9 MB  | ###7       |  37%
#
#
# pytorch-2.5.1        | 35.1 MB   | ######5    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dav1d-1.2.1          | 672 KB    | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.5.1          | 996 KB    | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 834 KB    | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dav1d-1.2.1          | 672 KB    | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 834 KB    | ###2       |  33%
#
#
# pytorch-2.5.1        | 35.1 MB   | ######6    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.5.1          | 996 KB    | ###2       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dav1d-1.2.1          | 672 KB    | ########## | 100%
# mkl-2023.1.0         | 155.9 MB  | ###8       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 834 KB    | ########4  |  84%
#
#
# pytorch-2.5.1        | 35.1 MB   | ######9    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 834 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.5.1          | 996 KB    | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.5.1          | 996 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# mkl-2023.1.0         | 155.9 MB  | ####       |  40%
#
#
# pytorch-2.5.1        | 35.1 MB   | #######2   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# pytorch-2.5.1        | 35.1 MB   | #######4   |  75%
# mkl-2023.1.0         | 155.9 MB  | ####1      |  41%
#
#
#
#
# sympy-1.14.0         | 11.5 MB   | ########## | 100%
#
#
# pytorch-2.5.1        | 35.1 MB   | #######7   |  77%
# mkl-2023.1.0         | 155.9 MB  | ####2      |  42%
#
#
# pytorch-2.5.1        | 35.1 MB   | ########1  |  81%
# mkl-2023.1.0         | 155.9 MB  | ####4      |  44%
#
#
# pytorch-2.5.1        | 35.1 MB   | ########3  |  84%
# mkl-2023.1.0         | 155.9 MB  | ####5      |  45%
#
#
# pytorch-2.5.1        | 35.1 MB   | ########7  |  88%
#
#
# pytorch-2.5.1        | 35.1 MB   | #########1 |  91%
# mkl-2023.1.0         | 155.9 MB  | ####6      |  46%
#
#
# pytorch-2.5.1        | 35.1 MB   | #########4 |  95%
# mkl-2023.1.0         | 155.9 MB  | ####7      |  47%
#
#
# pytorch-2.5.1        | 35.1 MB   | #########8 |  99%
# mkl-2023.1.0         | 155.9 MB  | ####8      |  48%
# mkl-2023.1.0         | 155.9 MB  | ####9      |  50%
# mkl-2023.1.0         | 155.9 MB  | #####      |  51%
#
#
# pytorch-2.5.1        | 35.1 MB   | ########## | 100%
# mkl-2023.1.0         | 155.9 MB  | #####2     |  53%
# mkl-2023.1.0         | 155.9 MB  | #####4     |  54%
# mkl-2023.1.0         | 155.9 MB  | #####6     |  56%
# mkl-2023.1.0         | 155.9 MB  | #####7     |  58%
# mkl-2023.1.0         | 155.9 MB  | #####9     |  59%
# mkl-2023.1.0         | 155.9 MB  | ######1    |  62%
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 7.5 MB    | ########## | 100%
# mkl-2023.1.0         | 155.9 MB  | ######4    |  64%
# mkl-2023.1.0         | 155.9 MB  | ######6    |  66%
#
#
#
#
#
#
#
#
# aom-3.12.1           | 5.5 MB    | ########## | 100%
# mkl-2023.1.0         | 155.9 MB  | ######8    |  68%
# mkl-2023.1.0         | 155.9 MB  | #######    |  70%
#
#
#
#
#
#
# numpy-base-2.0.1     | 9.1 MB    | ########## | 100%
# mkl-2023.1.0         | 155.9 MB  | #######2   |  72%
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | ########## | 100%
# mkl-2023.1.0         | 155.9 MB  | #######4   |  75%
# mkl-2023.1.0         | 155.9 MB  | #######6   |  77%
# mkl-2023.1.0         | 155.9 MB  | #######9   |  79%
# mkl-2023.1.0         | 155.9 MB  | ########1  |  81%
# mkl-2023.1.0         | 155.9 MB  | ########3  |  83%
# mkl-2023.1.0         | 155.9 MB  | ########5  |  85%
# mkl-2023.1.0         | 155.9 MB  | ########6  |  87%
# mkl-2023.1.0         | 155.9 MB  | ########8  |  89%
# mkl-2023.1.0         | 155.9 MB  | #########  |  91%
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 4.8 MB    | ########## | 100%
# mkl-2023.1.0         | 155.9 MB  | #########2 |  93%
# mkl-2023.1.0         | 155.9 MB  | #########4 |  95%
# mkl-2023.1.0         | 155.9 MB  | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20250127.0 | 1.9 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20250127.0 | 1.9 MB    | ########## | 100%
# mkl-2023.1.0         | 155.9 MB  | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | ########## | 100%
# mkl-2023.1.0         | 155.9 MB  | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.4       | 1.4 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.4       | 1.4 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dav1d-1.2.1          | 672 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dav1d-1.2.1          | 672 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 834 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.5.1          | 996 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 2.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 2.5 MB    | ########## | 100%
# mkl-2023.1.0         | 155.9 MB  | ########## | 100%
#
# libtorch-2.5.1       | 35.7 MB   | ########## | 100%
#
#
# pytorch-2.5.1        | 35.1 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pathlib, zipfile, urllib.request

root = pathlib.Path("kokoro_data")
root.mkdir(exist_ok=True)
zip_path = root / "kokoro-speech-v1_3.zip"

url = "https://github.com/kaiidams/Kokoro-Speech-Dataset/releases/download/1.3/kokoro-speech-v1_3.zip"
print(f"Downloading {url} …")
urllib.request.urlretrieve(url, zip_path)
print("Extracting …")
with zipfile.ZipFile(zip_path) as zf:
    zf.extractall(root)

print("Done.")
# Out:
# Downloading https://github.com/kaiidams/Kokoro-Speech-Dataset/releases/download/1.3/kokoro-speech-v1_3.zip …
# Extracting …
# Done.

# %%
import os
import json
import torchaudio
import torch

# Utility print for notebook
def err_print(*args, **kwargs):
    print(*args, **kwargs)

# --- Functions from original script ---
def read_params_list(data_dir, size):
    index_file = os.path.join(data_dir, 'index.json')
    if not os.path.exists(index_file):
        raise FileNotFoundError("`data/index.json` not found. Please download it from the project page.")

    with open(index_file) as f:
        params_list = json.load(f)

    return [
        params for params in params_list
        if (size == 'xlarge') or (size in params['sizes'].split())
    ]


def check_data_directory(data_dir, params_list):
    isok = True
    for params in params_list:
        id_ = params['id']
        audio_dir = os.path.join(data_dir, f'{id_}')
        if not os.path.isdir(audio_dir):
            err_print(f"Missing: `{audio_dir}`")
            isok = False
    if isok:
        err_print("✅ All audio directories exist.")
    return isok


def dump_script(data_dir, params_list):
    err_print('\n⚙️ Run these commands to download missing archives manually:\n')
    print(f'cd {data_dir}')
    for params in params_list:
        print(f'curl -LO {params["archive_url"]}')
    for params in params_list:
        archive_url = params['archive_url']
        archive_file = os.path.basename(archive_url)
        id_ = params['id']
        print(f"unzip {archive_file} -d {id_}")


def extract_wav_files(data_dir, params_list, clip_format, sample_rate, output_dir):
    clip_dir = 'wavs'
    clip_ext = clip_format
    os.makedirs(os.path.join(output_dir, clip_dir), exist_ok=True)
    max_int16 = torch.iinfo(torch.int16).max

    for params in params_list:
        id_ = params['id']
        metadata_file = os.path.join(data_dir, f'{id_}.metadata.txt')
        audio_dir = os.path.join(data_dir, f'{id_}')
        with open(metadata_file, 'rt') as metadata_f:
            current_file = None
            current_audio = None
            for line in metadata_f:
                parts = line.rstrip('\r\n').split('|')
                id_, audio_file, audio_start, audio_end, _, _ = parts
                audio_start, audio_end = int(audio_start), int(audio_end)
                if current_file != audio_file:
                    file = os.path.join(audio_dir, audio_file)
                    err_print(f'Reading {file}...')
                    y, sr = torchaudio.load(file)
                    assert len(y.shape) == 2 and y.shape[0] == 1
                    assert y.dtype == torch.float32
                    assert sr == sample_rate
                    y = (y * max_int16 / torch.max(torch.abs(y))).to(torch.int16)
                    current_file = audio_file
                    current_audio = y
                output_file = os.path.join(output_dir, clip_dir, f'{id_}.{clip_ext}')
                y = current_audio[:, audio_start:audio_end]
                torchaudio.save(output_file, y, sample_rate)


def write_metafile(data_dir, params_list, output_dir):
    metadata_outfile = os.path.join(output_dir, 'metadata.csv')
    with open(metadata_outfile, 'wt') as metadata_f:
        for params in params_list:
            id_ = params['id']
            metadata_file = os.path.join(data_dir, f'{id_}.metadata.txt')
            with open(metadata_file, 'rt') as transcript_f:
                for line in transcript_f:
                    parts = line.rstrip('\r\n').split('|')
                    id_, _, _, _, text, voca = parts
                    metadata_f.write(f'{id_}|{text}|{voca}\n')
    err_print(f"✅ Metadata written to {metadata_outfile}")

# --- Notebook main logic (instead of argparse) ---
data_dir = 'kokoro_data'           # @param ["data"] {allow-input: true}
output_dir = 'output'       # @param ["output"] {allow-input: true}
size = 'small'               # @param ["tiny", "small", "large", "xlarge"]
clip_format = 'wav'         # @param ["wav", "flac", "mp3", "ogg"]
sample_rate = 22050         # @param {type:"integer"}

# --- Run processing ---
params_list = read_params_list(data_dir, size)
if not params_list:
    raise ValueError(f"No matching params found for size '{size}'.")

if not check_data_directory(data_dir, params_list):
    dump_script(data_dir, params_list)
else:
    extract_wav_files(data_dir, params_list, clip_format, sample_rate, output_dir)
    write_metafile(data_dir, params_list, output_dir)
# Out:
# ✅ All audio directories exist.
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_01_natsume_64kb.mp3...
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_02_natsume_64kb.mp3...
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_03_natsume_64kb.mp3...
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_04_natsume_64kb.mp3...
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_05_natsume_64kb.mp3...
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_06_natsume_64kb.mp3...
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_07_natsume_64kb.mp3...
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_08_natsume_64kb.mp3...
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_09_natsume_64kb.mp3...
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_10_natsume_64kb.mp3...
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_11_natsume_64kb.mp3...
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_12_natsume_64kb.mp3...
# Reading kokoro_data\kusamakura-by-soseki-natsume\kusamakura_13_natsume_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_01_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_02_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_03_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_04_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_05_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_06_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_07_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_08_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_09_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_10_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_11_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_12_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_13_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_14_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_15_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_16_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_17_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_18_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_19_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_20_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_21_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_22_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_23_mori_64kb.mp3...
# Reading kokoro_data\gan-by-ogai-mori\gan_24_mori_64kb.mp3...
# ✅ Metadata written to output\metadata.csv

# %% [markdown]
# # To download the audio files if missing, just paste in the archive urls for each individual file

# %%
import pathlib, zipfile, urllib.request

root = pathlib.Path("kokoro_data")
root.mkdir(exist_ok=True)

sources = [
    ("http://www.archive.org/download/kusamakura_1311_librivox/kusamakura_1311_librivox_64kb_mp3.zip",
     "kusamakura-by-soseki-natsume"),
    ("http://www.archive.org/download/gan_1311_librivox/gan_1311_librivox_64kb_mp3.zip",
     "gan-by-ogai-mori"),
]

for url, folder_name in sources:
    zip_path = root / pathlib.Path(url).name
    target_dir = root / folder_name
    print(f"Downloading {url} …")
    urllib.request.urlretrieve(url, zip_path)
    print(f"Extracting to {target_dir} …")
    target_dir.mkdir(exist_ok=True)
    with zipfile.ZipFile(zip_path) as zf:
        zf.extractall(target_dir)
    print("Done.\n")
# Out:
# Downloading http://www.archive.org/download/kusamakura_1311_librivox/kusamakura_1311_librivox_64kb_mp3.zip …
# Extracting to kokoro_data\kusamakura-by-soseki-natsume …
# Done.
#
# Downloading http://www.archive.org/download/gan_1311_librivox/gan_1311_librivox_64kb_mp3.zip …
# Extracting to kokoro_data\gan-by-ogai-mori …
# Done.

# %% [markdown]
# # Process into needed files
#
# We are making lab files for the output and preprocessing

# %%
from pathlib import Path
import csv

out_dir = Path("./output")
wav_dir = out_dir / "wavs"

with (out_dir / "metadata.csv").open(encoding="utf8") as f:
    reader = csv.reader(f, delimiter="|")
    for utt_id, orth, *_ in reader:
        (wav_dir / f"{utt_id}.lab").write_text(orth.strip(), encoding="utf8")
